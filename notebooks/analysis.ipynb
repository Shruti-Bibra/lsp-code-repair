# %% [markdown]
# ## Import libraries

# %%
# !pip install genlm-control
# Out:
# Collecting genlm-control
#   Downloading genlm_control-0.2.12-py3-none-any.whl.metadata (8.8 kB)
# Collecting genlm-grammar>=0.2.0 (from genlm-control)
#   Downloading genlm_grammar-0.2.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting genlm-backend>=0.1.1 (from genlm-control)
#   Downloading genlm_backend-0.1.7-py3-none-any.whl.metadata (6.1 kB)
# Collecting llamppl (from genlm-control)
#   Downloading llamppl-0.2.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting arsenal>=3.1.3 (from genlm-control)
#   Downloading arsenal-3.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.12/dist-packages (from genlm-control) (7.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from genlm-control) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from genlm-control) (2.9.0+cu126)
# Collecting json-stream (from genlm-control)
#   Downloading json_stream-2.4.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: jsonschema[format-nongpl] in /usr/local/lib/python3.12/dist-packages (from genlm-control) (4.25.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from arsenal>=3.1.3->genlm-control) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from arsenal>=3.1.3->genlm-control) (2.2.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from arsenal>=3.1.3->genlm-control) (3.0.12)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from arsenal>=3.1.3->genlm-control) (3.10.0)
# Collecting gprof2dot (from arsenal>=3.1.3->genlm-control)
#   Downloading gprof2dot-2025.4.14-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from arsenal>=3.1.3->genlm-control) (0.21)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from arsenal>=3.1.3->genlm-control) (13.9.4)
# Collecting path.py (from arsenal>=3.1.3->genlm-control)
#   Downloading path.py-12.5.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from arsenal>=3.1.3->genlm-control) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from arsenal>=3.1.3->genlm-control) (5.9.5)
# Requirement already satisfied: transformers>=4.36.0 in /usr/local/lib/python3.12/dist-packages (from genlm-backend>=0.1.1->genlm-control) (4.57.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from genlm-backend>=0.1.1->genlm-control) (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from genlm-backend>=0.1.1->genlm-control) (5.29.5)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from genlm-backend>=0.1.1->genlm-control) (1.12.0)
# Collecting bitsandbytes (from genlm-backend>=0.1.1->genlm-control)
#   Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from genlm-backend>=0.1.1->genlm-control) (0.60.0)
# Collecting vllm<=0.10.0,>=0.6.6 (from genlm-backend>=0.1.1->genlm-control)
#   Downloading vllm-0.10.0-cp38-abi3-manylinux1_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: triton>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from genlm-backend>=0.1.1->genlm-control) (3.5.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from genlm-grammar>=0.2.0->genlm-control) (2.4.7)
# Collecting interegular (from genlm-grammar>=0.2.0->genlm-control)
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: lark in /usr/local/lib/python3.12/dist-packages (from genlm-grammar>=0.2.0->genlm-control) (1.3.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from genlm-grammar>=0.2.0->genlm-control) (3.9.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (75.2.0)
# Collecting jedi>=0.16 (from IPython->genlm-control)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from IPython->genlm-control) (4.9.0)
# Collecting json-stream-rs-tokenizer>=0.4.17 (from json-stream->genlm-control)
#   Downloading json_stream_rs_tokenizer-0.4.32-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (0.30.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (1.5.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (3.11)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (3.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (0.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]->genlm-control) (25.10.0)
# Collecting pre-commit>=3.7.1 (from llamppl->genlm-control)
#   Downloading pre_commit-4.5.1-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting ipykernel>=6.29.5 (from llamppl->genlm-control)
#   Downloading ipykernel-7.1.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->genlm-control) (1.11.1.6)
# Collecting comm>=0.1.1 (from ipykernel>=6.29.5->llamppl->genlm-control)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->llamppl->genlm-control) (1.8.15)
# Collecting jupyter-client>=8.0.0 (from ipykernel>=6.29.5->llamppl->genlm-control)
#   Downloading jupyter_client-8.7.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->llamppl->genlm-control) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->llamppl->genlm-control) (1.6.0)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->llamppl->genlm-control) (25.0)
# Requirement already satisfied: pyzmq>=25 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->llamppl->genlm-control) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->llamppl->genlm-control) (6.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->IPython->genlm-control) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->IPython->genlm-control) (0.7.0)
# Collecting cfgv>=2.0.0 (from pre-commit>=3.7.1->llamppl->genlm-control)
#   Downloading cfgv-3.5.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting identify>=1.0.0 (from pre-commit>=3.7.1->llamppl->genlm-control)
#   Downloading identify-2.6.15-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit>=3.7.1->llamppl->genlm-control)
#   Downloading nodeenv-1.10.0-py2.py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.7.1->llamppl->genlm-control) (6.0.3)
# Collecting virtualenv>=20.10.0 (from pre-commit>=3.7.1->llamppl->genlm-control)
#   Downloading virtualenv-20.35.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->genlm-control) (0.2.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->genlm-control) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (0.7.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (6.2.4)
# Collecting blake3 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (9.0.0)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.123.10)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (3.13.2)
# Collecting openai<=1.90.0,>=1.87.0 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading openai-1.90.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: pydantic>=2.10 in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (2.12.3)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.23.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (11.3.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.12.0)
# Collecting lm-format-enforcer<0.11,>=0.10.11 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading lm_format_enforcer-0.10.12-py3-none-any.whl.metadata (17 kB)
# Collecting llguidance<0.8.0,>=0.7.11 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading llguidance-0.7.30-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting outlines_core==0.2.10 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading outlines_core-0.2.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting diskcache==5.6.3 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting lark (from genlm-grammar>=0.2.0->genlm-control)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar==0.1.21 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading xgrammar-0.1.21-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Collecting partial-json-parser (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading partial_json_parser-0.2.1.1.post7-py3-none-any.whl.metadata (6.1 kB)
# Collecting msgspec (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting gguf>=0.13.0 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading gguf-0.17.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting mistral_common>=1.8.2 (from mistral_common[audio,image]>=1.8.2->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading mistral_common-1.8.8-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (4.12.0.88)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.17.0)
# Collecting setuptools>=18.5 (from IPython->genlm-control)
#   Downloading setuptools-79.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.8.1)
# Collecting compressed-tensors==0.10.2 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading compressed_tensors-0.10.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting depyf==0.19.0 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading depyf-0.19.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (3.1.2)
# Collecting watchfiles (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading watchfiles-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (4.0.0)
# Collecting ninja (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting pybase64 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting cbor2 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading cbor2-5.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting numba (from genlm-backend>=0.1.1->genlm-control)
#   Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting ray!=2.44.*,>=2.43.0 (from ray[cgraph]!=2.44.*,>=2.43.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading ray-2.53.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting torch (from genlm-control)
#   Downloading torch-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchaudio==2.7.1 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading torchaudio-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting torchvision==0.22.1 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading torchvision-0.22.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting xformers==0.0.31 (from vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading xformers-0.0.31-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch->genlm-control)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch->genlm-control)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch->genlm-control)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting triton>=3.2.0 (from genlm-backend>=0.1.1->genlm-control)
#   Downloading triton-3.3.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba->genlm-backend>=0.1.1->genlm-control)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting astor (from depyf==0.19.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from depyf==0.19.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.3.8)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]->genlm-control) (1.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->genlm-control) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arsenal>=3.1.3->genlm-control) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arsenal>=3.1.3->genlm-control) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arsenal>=3.1.3->genlm-control) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arsenal>=3.1.3->genlm-control) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arsenal>=3.1.3->genlm-control) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arsenal>=3.1.3->genlm-control) (2.9.0.post0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->genlm-grammar>=0.2.0->genlm-control) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->genlm-grammar>=0.2.0->genlm-control) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->arsenal>=3.1.3->genlm-control) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->arsenal>=3.1.3->genlm-control) (2025.3)
# Collecting path (from path.py->arsenal>=3.1.3->genlm-control)
#   Downloading path-17.1.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->arsenal>=3.1.3->genlm-control) (4.0.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.0.4)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading fastapi_cli-0.0.20-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.28.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.0.20)
# Collecting email-validator>=2.0.0 (from fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.38.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (1.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->llamppl->genlm-control) (4.5.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->arsenal>=3.1.3->genlm-control) (0.1.2)
# Collecting pydantic-extra-types>=2.10.5 (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading pydantic_extra_types-2.10.6-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<=1.90.0,>=1.87.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<=1.90.0,>=1.87.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<=1.90.0,>=1.87.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<=1.90.0,>=1.87.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.4.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray!=2.44.*,>=2.43.0->ray[cgraph]!=2.44.*,>=2.43.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.1.2)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]!=2.44.*,>=2.43.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (13.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.36.0->genlm-backend>=0.1.1->genlm-control) (2025.11.12)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit>=3.7.1->llamppl->genlm-control)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.22.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.20.0)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading rich_toolkit-0.17.1-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading fastapi_cloud_cli-0.7.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.16.0)
# Collecting pycountry>=23 (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading httptools-0.7.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.2.1)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading uvloop-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (15.0.1)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x->ray[cgraph]!=2.44.*,>=2.43.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.8.3)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (0.13.1)
# Requirement already satisfied: soxr>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.0.0)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (2.47.0)
# Collecting fastar>=0.8.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control)
#   Downloading fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (2.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<=0.10.0,>=0.6.6->genlm-backend>=0.1.1->genlm-control) (2.23)
# Downloading genlm_control-0.2.12-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.5 MB/s eta 0:00:00
# Downloading arsenal-3.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.3 MB/s eta 0:00:00
# Downloading genlm_backend-0.1.7-py3-none-any.whl (35 kB)
# Downloading genlm_grammar-0.2.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.0 MB/s eta 0:00:00
# Downloading json_stream-2.4.1-py3-none-any.whl (35 kB)
# Downloading llamppl-0.2.2-py3-none-any.whl (28 kB)
# Downloading ipykernel-7.1.0-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 12.3 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.6 MB/s eta 0:00:00
# Downloading json_stream_rs_tokenizer-0.4.32-cp312-cp312-manylinux_2_28_x86_64.whl (334 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.9/334.9 kB 29.9 MB/s eta 0:00:00
# Downloading pre_commit-4.5.1-py2.py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 20.4 MB/s eta 0:00:00
# Downloading vllm-0.10.0-cp38-abi3-manylinux1_x86_64.whl (386.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 MB 1.5 MB/s eta 0:00:00
# Downloading torch-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl (821.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.0/821.0 MB 1.5 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/2d/00/d90b10b962b4277f5e64a78b6609968859ff86889f5b898c1a778c06ec00/lark-1.2.2-py3-none-any.whl
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 10.0 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 91.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 891.0 kB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 6.9 MB/s eta 0:00:00
# Downloading triton-3.3.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 7.1 MB/s eta 0:00:00
# Downloading compressed_tensors-0.10.2-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 17.1 MB/s eta 0:00:00
# Downloading depyf-0.19.0-py3-none-any.whl (39 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.5 MB/s eta 0:00:00
# Downloading outlines_core-0.2.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 99.1 MB/s eta 0:00:00
# Downloading torchaudio-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 122.2 MB/s eta 0:00:00
# Downloading torchvision-0.22.1-cp312-cp312-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 125.7 MB/s eta 0:00:00
# Downloading xformers-0.0.31-cp39-abi3-manylinux_2_28_x86_64.whl (117.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 MB 7.9 MB/s eta 0:00:00
# Downloading xgrammar-0.1.21-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 147.9 MB/s eta 0:00:00
# Downloading setuptools-79.0.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.3 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 13.4 MB/s eta 0:00:00
# Downloading gprof2dot-2025.4.14-py3-none-any.whl (37 kB)
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading path.py-12.5.0-py3-none-any.whl (2.3 kB)
# Downloading cfgv-3.5.0-py2.py3-none-any.whl (7.4 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading gguf-0.17.1-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 10.9 MB/s eta 0:00:00
# Downloading identify-2.6.15-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 10.7 MB/s eta 0:00:00
# Downloading jupyter_client-8.7.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 11.9 MB/s eta 0:00:00
# Downloading llguidance-0.7.30-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 109.0 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 15.7 MB/s eta 0:00:00
# Downloading lm_format_enforcer-0.10.12-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 4.5 MB/s eta 0:00:00
# Downloading mistral_common-1.8.8-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 120.3 MB/s eta 0:00:00
# Downloading nodeenv-1.10.0-py2.py3-none-any.whl (23 kB)
# Downloading openai-1.90.0-py3-none-any.whl (734 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.6/734.6 kB 55.8 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl (19 kB)
# Downloading ray-2.53.0-cp312-cp312-manylinux2014_x86_64.whl (72.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 MB 10.2 MB/s eta 0:00:00
# Downloading virtualenv-20.35.4-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 153.2 MB/s eta 0:00:00
# Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 37.7 MB/s eta 0:00:00
# Downloading cbor2-5.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.7/285.7 kB 28.0 MB/s eta 0:00:00
# Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 22.7 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 19.7 MB/s eta 0:00:00
# Downloading partial_json_parser-0.2.1.1.post7-py3-none-any.whl (10 kB)
# Downloading path-17.1.1-py3-none-any.whl (23 kB)
# Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 8.0 MB/s eta 0:00:00
# Downloading watchfiles-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (456 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.8/456.8 kB 29.6 MB/s eta 0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 41.0 MB/s eta 0:00:00
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading fastapi_cli-0.0.20-py3-none-any.whl (12 kB)
# Downloading pydantic_extra_types-2.10.6-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.5 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 33.9 MB/s eta 0:00:00
# Downloading fastapi_cloud_cli-0.7.0-py3-none-any.whl (23 kB)
# Downloading httptools-0.7.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (517 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.7/517.7 kB 44.4 MB/s eta 0:00:00
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 142.4 MB/s eta 0:00:00
# Downloading rich_toolkit-0.17.1-py3-none-any.whl (31 kB)
# Downloading uvloop-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 117.2 MB/s eta 0:00:00
# Downloading fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 63.7 MB/s eta 0:00:00
# Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (959 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 68.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, distlib, virtualenv, uvloop, setuptools, rignore, pycountry, pybase64, path, partial-json-parser, outlines_core, nvidia-nccl-cu12, nvidia-cudnn-cu12, nodeenv, ninja, msgspec, llvmlite, llguidance, lark, json-stream-rs-tokenizer, jedi, interegular, identify, httptools, gprof2dot, gguf, fastar, dnspython, diskcache, comm, cfgv, cbor2, blake3, astor, watchfiles, triton, pre-commit, path.py, numba, jupyter-client, json-stream, email-validator, depyf, torch, rich-toolkit, pydantic-extra-types, prometheus-fastapi-instrumentator, openai, lm-format-enforcer, ipykernel, arsenal, xformers, torchvision, torchaudio, ray, genlm-grammar, fastapi-cloud-cli, fastapi-cli, bitsandbytes, xgrammar, mistral_common, compressed-tensors, vllm, genlm-backend, llamppl, genlm-control
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: lark
#     Found existing installation: lark 1.3.1
#     Uninstalling lark-1.3.1:
#       Successfully uninstalled lark-1.3.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.5.0
#     Uninstalling triton-3.5.0:
#       Successfully uninstalled triton-3.5.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.4.9
#     Uninstalling jupyter_client-7.4.9:
#       Successfully uninstalled jupyter_client-7.4.9
#   Attempting uninstall: torch
#     Found existing installation: torch 2.9.0+cu126
#     Uninstalling torch-2.9.0+cu126:
#       Successfully uninstalled torch-2.9.0+cu126
#   Attempting uninstall: openai
#     Found existing installation: openai 2.12.0
#     Uninstalling openai-2.12.0:
#       Successfully uninstalled openai-2.12.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.24.0+cu126
#     Uninstalling torchvision-0.24.0+cu126:
#       Successfully uninstalled torchvision-0.24.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.9.0+cu126
#     Uninstalling torchaudio-2.9.0+cu126:
#       Successfully uninstalled torchaudio-2.9.0+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 7.1.0 which is incompatible.
# notebook 6.5.7 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.7.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.7.0 which is incompatible.
# Successfully installed arsenal-3.1.3 astor-0.8.1 bitsandbytes-0.49.0 blake3-1.0.8 cbor2-5.7.1 cfgv-3.5.0 comm-0.2.3 compressed-tensors-0.10.2 depyf-0.19.0 diskcache-5.6.3 distlib-0.4.0 dnspython-2.8.0 email-validator-2.3.0 fastapi-cli-0.0.20 fastapi-cloud-cli-0.7.0 fastar-0.8.0 genlm-backend-0.1.7 genlm-control-0.2.12 genlm-grammar-0.2.0 gguf-0.17.1 gprof2dot-2025.4.14 httptools-0.7.1 identify-2.6.15 interegular-0.3.3 ipykernel-7.1.0 jedi-0.19.2 json-stream-2.4.1 json-stream-rs-tokenizer-0.4.32 jupyter-client-8.7.0 lark-1.2.2 llamppl-0.2.2 llguidance-0.7.30 llvmlite-0.44.0 lm-format-enforcer-0.10.12 mistral_common-1.8.8 msgspec-0.20.0 ninja-1.13.0 nodeenv-1.10.0 numba-0.61.2 nvidia-cudnn-cu12-9.5.1.17 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 openai-1.90.0 outlines_core-0.2.10 partial-json-parser-0.2.1.1.post7 path-17.1.1 path.py-12.5.0 pre-commit-4.5.1 prometheus-fastapi-instrumentator-7.1.0 pybase64-1.4.3 pycountry-24.6.1 pydantic-extra-types-2.10.6 ray-2.53.0 rich-toolkit-0.17.1 rignore-0.7.6 setuptools-79.0.1 torch-2.7.1 torchaudio-2.7.1 torchvision-0.22.1 triton-3.3.1 uvloop-0.22.1 virtualenv-20.35.4 vllm-0.10.0 watchfiles-1.1.1 xformers-0.0.31 xgrammar-0.1.21

# %%
# !pip install pyright
# Out:
# Collecting pyright
#   Downloading pyright-1.1.407-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: nodeenv>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pyright) (1.10.0)
# Requirement already satisfied: typing-extensions>=4.1 in /usr/local/lib/python3.12/dist-packages (from pyright) (4.15.0)
# Downloading pyright-1.1.407-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 47.9 MB/s eta 0:00:00
# Installing collected packages: pyright
# Successfully installed pyright-1.1.407

# %%
pip install -U dspy
# Out:
# Collecting dspy
#   Downloading dspy-3.0.4-py3-none-any.whl.metadata (8.4 kB)
# Collecting backoff>=2.2 (from dspy)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: joblib~=1.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (1.5.3)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (1.90.0)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (2025.11.3)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.11.5)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (4.67.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.32.4)
# Collecting optuna>=3.4.0 (from dspy)
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.12.3)
# Collecting magicattr>=0.1.6 (from dspy)
#   Downloading magicattr-0.1.6-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting litellm>=1.64.0 (from dspy)
#   Downloading litellm-1.80.11-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: diskcache>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (5.6.3)
# Collecting json-repair>=0.30.0 (from dspy)
#   Downloading json_repair-0.54.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (9.1.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy) (4.12.0)
# Collecting asyncer==0.0.8 (from dspy)
#   Downloading asyncer-0.0.8-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (6.2.4)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.1.2)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (13.9.4)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (11.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.6.0)
# Collecting gepa==0.0.17 (from gepa[dspy]==0.0.17->dspy)
#   Downloading gepa-0.0.17-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy) (3.11)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy) (4.15.0)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (3.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (8.3.1)
# Collecting fastuuid>=0.13.0 (from litellm>=1.64.0->dspy)
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting grpcio<1.68.0,>=1.62.3 (from litellm>=1.64.0->dspy)
#   Downloading grpcio-1.67.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (4.25.1)
# Collecting openai>=0.28.1 (from dspy)
#   Downloading openai-2.14.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (1.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.22.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (1.3.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (1.17.2)
# Collecting colorlog (from optuna>=3.4.0->dspy)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (2.0.45)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy) (1.3.10)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.64.0->dspy) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->dspy) (0.1.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.4.0->dspy) (3.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm>=1.64.0->dspy) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (1.2.0)
# Downloading dspy-3.0.4-py3-none-any.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.2/285.2 kB 23.5 MB/s eta 0:00:00
# Downloading asyncer-0.0.8-py3-none-any.whl (9.2 kB)
# Downloading gepa-0.0.17-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.3 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading json_repair-0.54.3-py3-none-any.whl (29 kB)
# Downloading litellm-1.80.11-py3-none-any.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 82.3 MB/s eta 0:00:00
# Downloading magicattr-0.1.6-py2.py3-none-any.whl (4.7 kB)
# Downloading openai-2.14.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.0 MB/s eta 0:00:00
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 21.4 MB/s eta 0:00:00
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 21.7 MB/s eta 0:00:00
# Downloading grpcio-1.67.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 75.7 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: magicattr, json-repair, grpcio, gepa, fastuuid, colorlog, backoff, asyncer, optuna, openai, litellm, dspy
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.76.0
#     Uninstalling grpcio-1.76.0:
#       Successfully uninstalled grpcio-1.76.0
#   Attempting uninstall: openai
#     Found existing installation: openai 1.90.0
#     Uninstalling openai-1.90.0:
#       Successfully uninstalled openai-1.90.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.10.0 requires openai<=1.90.0,>=1.87.0, but you have openai 2.14.0 which is incompatible.
# grpcio-status 1.71.2 requires grpcio>=1.71.2, but you have grpcio 1.67.1 which is incompatible.
# Successfully installed asyncer-0.0.8 backoff-2.2.1 colorlog-6.10.1 dspy-3.0.4 fastuuid-0.14.0 gepa-0.0.17 grpcio-1.67.1 json-repair-0.54.3 litellm-1.80.11 magicattr-0.1.6 openai-2.14.0 optuna-4.6.0

# %%
pip install transformers accelerate

# %%
import ast
import asyncio
import logging
import json
import torch
import re
import dspy
from typing import List, Dict
from genlm.control.potential.base import Potential
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
logger = logging.getLogger(__name__)

# %% [markdown]
# ## LSP potential updated with diagnostic messages function

# %%
class LSP(Potential):
    def __init__(
        self,
        lsp_command: list[str],
    ):
        super().__init__(vocabulary=list(range(256)))
        self.lsp_command = lsp_command
        self.lsp_process = None
        self.request_id = 1
        self.stderr_task = None
        logger.info(
            f"LSPPotential initialized with command: {self.lsp_command}"
        )

    async def _read_stderr(self):
        """Reads from the LSP server's stderr and logs it."""
        while (
            self.lsp_process
            and self.lsp_process.stderr
            and not self.lsp_process.stderr.at_eof()
        ):
            try:
                line = await self.lsp_process.stderr.readline()
                if line:
                    logger.error(f"[LSP stderr] {line.decode().strip()}")
            except Exception as e:
                logger.error(f"Error reading LSP stderr: {e}")
                break

    async def _lint(self, code: str) -> float:
        """Helper method to initialize server if needed and get diagnostics."""
        if not self.lsp_process or self.lsp_process.returncode is not None:
            await self.initialize_server()

        diagnostics = await self.get_diagnostics(code)
        for d in diagnostics:
            if d.get("severity") == 1:  # 1 is for Error
                logger.warning(f"LSP Error found: {d['message']}")
                return float("-inf")  # Penalize heavily

        return 0.0  # No errors found

    async def start_server(
        self,
    ):
        """Starts the LSP server as a subprocess."""

        if self.lsp_process and self.lsp_process.returncode is None:
            logger.info("LSP server already running.")
            return

        try:
            logger.info(
                f"Starting LSP server with command: {' '.join(self.lsp_command)}"
            )
            self.lsp_process = await asyncio.create_subprocess_exec(
                *self.lsp_command,
                stdin=asyncio.subprocess.PIPE,
                stdout=asyncio.subprocess.PIPE,
                stderr=asyncio.subprocess.PIPE,
            )
            logger.info(f"LSP server started with PID: {self.lsp_process.pid}")
            self.stderr_task = asyncio.create_task(self._read_stderr())
        except FileNotFoundError:
            logger.error(
                f"LSP command not found: {self.lsp_command[0]}. Please ensure it's installed and in your PATH."
            )
            raise
        except Exception as e:
            logger.error(f"Failed to start LSP server: {e}")
            raise

    async def _send_message(
        self,
        message: dict,
    ):
        if not self.lsp_process or not self.lsp_process.stdin:
            raise ConnectionError("LSP server is not running.")

        json_message = json.dumps(message)
        body = json_message.encode("utf-8")
        header = f"Content-Length: {len(body)}\r\n\r\n".encode("utf-8")
        self.lsp_process.stdin.write(header + body)
        await self.lsp_process.stdin.drain()
        logger.debug(f"Sent: {json_message}")

    async def _read_message(
        self,
    ) -> dict:
        if not self.lsp_process or not self.lsp_process.stdout:
            raise ConnectionError("LSP server is not running.")
        header_bytes = await self.lsp_process.stdout.readuntil(b"\r\n\r\n")
        header = header_bytes.decode("utf-8")
        content_length_str = header.strip().split(": ")[1]
        content_length = int(content_length_str)
        body_bytes = await self.lsp_process.stdout.readexactly(content_length)
        body = body_bytes.decode("utf-8")
        logger.debug(f"Received: {body}")
        return json.loads(body)

    async def initialize_server(
        self,
    ):
        await self.start_server()
        init_request = {
            "jsonrpc": "2.0",
            "id": self.request_id,
            "method": "initialize",
            "params": {
                "processId": None,
                "rootUri": None,
                "capabilities": {},
            },
        }
        await self._send_message(init_request)
        self.request_id += 1
        response = await self._read_message()
        if "error" in response:
            raise RuntimeError(
                f"LSP server failed to initialize: {response['error']}"
            )
        logger.info("Server initialized successfully.")
        await self._send_message(
            {
                "jsonrpc": "2.0",
                "method": "initialized",
                "params": {},
            }
        )
        logger.info("Sent 'initialized' notification.")

    async def get_diagnostics(
        self,
        code: str,
    ) -> list:
        doc_uri = "file:///temp_file.py"

        open_notification = {
            "jsonrpc": "2.0",
            "method": "textDocument/didOpen",
            "params": {
                "textDocument": {
                    "uri": doc_uri,
                    "languageId": "python",
                    "version": 1,
                    "text": code,
                }
            },
        }
        await self._send_message(open_notification)

        try:
            while True:
                message = await asyncio.wait_for(
                    self._read_message(), timeout=2.0
                )
                # Check if the message is the diagnostic notification we're waiting for
                if message.get("method") == "textDocument/publishDiagnostics":
                    if message["params"]["uri"] == doc_uri:
                        logger.info(
                            f"Received diagnostics for {doc_uri}: {message['params']['diagnostics']}"
                        )
                        # We got them! Return the diagnostics
                        return message["params"]["diagnostics"]
                    else:
                        logger.debug(
                            f"Ignoring diagnostics for other document: {message['params']['uri']}"
                        )
                else:
                    logger.debug(f"Ignoring LSP message: {message}")
        except asyncio.TimeoutError:
            logger.warning(f"Timed out waiting for diagnostics for {doc_uri}")
            return []

    async def prefix(
        self,
        context,
    ):
        try:
            code = context.decode("utf-8")
        except UnicodeDecodeError:
            return float("-inf")
        try:
            ast.parse(code)
        except (
            SyntaxError,
            IndentationError,
        ):
            return 0.0
        return await self._lint(code)

    async def complete(
        self,
        context,
    ):

        # The 'complete' method should lint the final output.
        # Its logic is very similar to 'prefix' but it doesn't need the ast.parse check.
        try:
            code = context.decode("utf-8")
        except UnicodeDecodeError:
            return float("-inf")
        if not self.lsp_process or self.lsp_process.returncode is not None:
            await self.initialize_server()
        return await self._lint(code)

    async def close(
        self,
    ):
        if not self.lsp_process or self.lsp_process.returncode is not None:
            return
        shutdown_req = {
            "jsonrpc": "2.0",
            "id": self.request_id,
            "method": "shutdown",
        }
        await self._send_message(shutdown_req)
        await self._read_message()  # Wait for shutdown response

        await self._send_message(
            {
                "jsonrpc": "2.0",
                "method": "exit",
            }
        )

        if self.stderr_task:
            self.stderr_task.cancel()
        try:
            await self.stderr_task
        except asyncio.CancelledError:
            pass

        await self.lsp_process.wait()
        logger.info("LSP server shut down gracefully.")
        self.lsp_process = None

    def __repr__(
        self,
    ):
        return f"LSP(lsp_command={self.lsp_command})"

    def spawn(
        self,
    ):
        return LSP(self.lsp_command)

    # Get the correct diagnostics info --------- linter error message

    async def diagnostic_messages(self, code: str):
            """
            Return normalized diagnostics with message, severity score,
            and code range.
            """

            if isinstance(code, bytes):
                code = code.decode("utf-8", errors="replace")

            if not self.lsp_process or self.lsp_process.returncode is not None:
                await self.initialize_server()

            raw_diagnostics = await self.get_diagnostics(code)

            normalized = []

            for d in raw_diagnostics:
                severity = d.get("severity", 3)

                normalized.append({
                    "message": d.get("message", "No error found"),
                    "severity": severity,
                    "range": {
                        "start": {
                            "line": d["range"]["start"]["line"],
                            "character": d["range"]["start"]["character"],
                        },
                        "end": {
                            "line": d["range"]["end"]["line"],
                            "character": d["range"]["end"]["character"],
                        },
                    }
                })

            return normalized

# %% [markdown]
# ## Diagnostic message function test

# %%
lsp = LSP(["pyright-langserver", "--stdio"])

code = b"""def add(a: int, b: int) -> int:\n    return 'hello' """

normalized_diagnostics = await lsp.diagnostic_messages(code.decode("utf-8"))
print(normalized_diagnostics)

# %% [markdown]
# ## DSPY

# %%
lm = dspy.LM("gemini/gemini-2.5-flash", api_key=API_KEY)
dspy.configure(lm=lm)

# %%
class DSPyRepair(dspy.Signature):
    faulty_code: str = dspy.InputField(default="", desc="Faulty code")
    diagnostics: str = dspy.InputField(default="", desc="Normalized diagnostics")
    answer: str = dspy.OutputField(default=None, desc="Corrected code")

    def repair_code(self, code: str, diagnostics: list[dict], N: int = 6) -> str:
        """
        Use DSPy Refine to repair code with automatic feedback.
        - code: faulty Python code
        - diagnostics: list of normalized diagnostics
        - N: number of refinement iterations
        """
        diagnostics_json = json.dumps(diagnostics)

        # Define reward function (optional: can integrate LSP scoring later)
        def reward_fn(args, pred: dspy.Prediction) -> float:
            # Simple reward: +1 if code parses, else 0
            try:
                import ast
                ast.parse(pred.answer)
                return 1.0
            except Exception:
                return 0.0

        # Refine module replaces single Predict call
        refine_module = dspy.Refine(
            module=dspy.Predict(
                "faulty_code, diagnostics -> answer"
            ),
            N=N,
            reward_fn=reward_fn,
            threshold=1.0  # stops early if reward meets threshold
        )

        # Run Refine
        result = refine_module(
            question=f"""
            You are a Python code repair assistant.
            Return ONLY a JSON object with key "answer" containing the corrected Python code as a string.
            DONOT change the code, only return the corrected code.
            Inputs:
            faulty_code: {code}
            diagnostics: {diagnostics_json}
            """
        )

        # Return the best corrected code
        return result.answer

# %% [markdown]
# ## Test Cases

# %%
TEST_CASES = [
    {
        "name": "Correct, complete code",
        "code": b"import os\n\ndef my_func():\n    return os.getcwd()",
        "expected_score": 0.0,
    },
    {
        "name": "Code with an undefined variable error",
        "code": b"def my_func():\n    print(undeclared_variable)",
        "expected_score": float("-inf"),
    },
    {
        "name": "Incomplete code (open function signature)",
        "code": b"def my_func(",
        "expected_score": 0.0,
    },
    {
        "name": "Incomplete code (if statement with no body)",
        "code": b"def my_func(x):\n    if x > 10:",
        "expected_score": 0.0,
    },
    {
        "name": "Syntactically valid code with a type error",
        "code": b"def add(a: int, b: int) -> int:\n    return 'hello'",
        "expected_score": float("-inf"),
    },
    {
        "name": "Empty code",
        "code": b"",
        "expected_score": 0.0,
    },
    {
        "name": "Code with only whitespace",
        "code": b"    \n  ",
        "expected_score": 0.0,
    },
    {
        "name": "Code importing a non-existent module",
        "code": b"import a_module_that_does_not_exist",
        "expected_score": float("-inf"),
    },
]

# %% [markdown]
# ## DSPy test

# %%
results = []
lsp = LSP(["pyright-langserver", "--stdio"])

for test in TEST_CASES:
  code_bytes = test["code"]
  code_str = code_bytes.decode() if isinstance(code_bytes, bytes) else code_bytes

  diagnostics = await lsp.diagnostic_messages(code_str)

  dspy_repair = DSPyRepair()
  corrected = dspy_repair.repair_code(code=code_str, diagnostics=diagnostics)

  results.append({
            "name": test["name"],
            "original_code": code_str,
            "dspy_code": corrected,
            "diagnostics": diagnostics
        })

  print(f"Test '{test['name']}' done.")

with open("dspy_test_results.json", "w") as f:
    json.dump(results, f, indent=4)

# %% [markdown]
# ## Evaluation

# %%
class Evaluator:
    def __init__(self, lsp):
        self.lsp = lsp
        # Load Qwen model
        self.model_name = "Qwen/Qwen3-14B"
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name,
            torch_dtype="auto",
            device_map="auto"
        )

    def deterministic_score(self, diagnostics: List[Dict]) -> float:
        """
        Compute a deterministic score based on severity:
        - Error (1) = -10
        - Warning (2) = -5
        - Info (3) = -1
        - Hint (4) = 0
        Higher score is better (less severe issues).
        """
        score = 0.0
        severity_penalties = {1: -10, 2: -5, 3: -1, 4: 0}
        for d in diagnostics:
            sev = d.get("severity", 3)
            penalty = severity_penalties.get(sev, -1)
            score += penalty
        return score

    async def get_normalized_diagnostics(self, code: bytes) -> List[Dict]:
        code_str = code.decode("utf-8", errors="replace")
        normalized_diagnostics = await self.lsp.diagnostic_messages(code_str)
        return normalized_diagnostics

    def llm_judge(self, old_code: str, new_code: str, max_score: int = 5) -> float:
        """
        Evaluate the corrected code using Qwen.
        Scores from 0 to max_score based on:
        - Semantic correctness (does new_code fix the issues in old_code?)
        - Preservation of original logic (no unnecessary changes)
        - Readability and code quality
        """
        prompt = f"""
                      You are an expert Python code evaluator.

                      Original code:
                      {old_code}

                      Corrected code:
                      {new_code}

                      Score the corrected code from 0 (worst) to {max_score} (best) based on:
                      1. Semantic correctness: does it fix the errors?
                      2. Preservation of original logic: does it avoid unnecessary changes?
                      3. Readability and code quality: is it clear and Pythonic?

                      Return the numeric score with a short reasoning in one sentence. The example is given below
                      Example:
                      Semantic correctness : 4
                      Preservation of original logic : 5
                      Readability and code quality : 5
                      and one line of reasoning
                  """

        messages = [{"role": "user", "content": prompt}]
        text = self.tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=True
        )
        model_inputs = self.tokenizer([text], return_tensors="pt").to(self.model.device)

        generated_ids = self.model.generate(
            **model_inputs,
            max_new_tokens=256
        )
        # Skip the prompt tokens
        output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()
        output_text = self.tokenizer.decode(output_ids, skip_special_tokens=True).strip()


        return output_text

# %%
evaluator = Evaluator(lsp)

# %% [markdown]
# ## Runner

# %%
async def evaluate_test_cases(
    input_json_path: str,
    output_json_path: str,
    evaluator
):
    # Load test cases
    with open(input_json_path, "r", encoding="utf-8") as f:
        test_cases: List[Dict] = json.load(f)

    for case in test_cases:
        print(f"Evaluating: {case.get('name', 'unnamed test')}")

        # ---------------------------
        # Step 1: deterministic score BEFORE
        # ---------------------------
        diagnostics_before = case.get("diagnostics", [])
        case["deterministic_score_before"] = evaluator.deterministic_score(
            diagnostics_before
        )

        # ---------------------------
        # Step 2: deterministic score AFTER (normalized diagnostics)
        # ---------------------------
        dspy_code = case.get("dspy_code", "")
        normalized_diagnostics = await evaluator.get_normalized_diagnostics(
            dspy_code.encode("utf-8")
        )

        case["normalized_diagnostics"] = normalized_diagnostics
        case["deterministic_score_after"] = evaluator.deterministic_score(
            normalized_diagnostics
        )

        # ---------------------------
        # Step 3: LLM as Judge
        # ---------------------------
        original_code = case.get("original_code", "")
        case["llm_judge_score"] = evaluator.llm_judge(
            original_code=original_code,
            new_code=dspy_code
        )

    # Save updated JSON
    with open(output_json_path, "w", encoding="utf-8") as f:
        json.dump(test_cases, f, indent=2)

    print(f"Evaluation complete. Results saved to {output_json_path}")

# %%
lsp = LSP(["pyright-langserver", "--stdio"])
evaluator = Evaluator(lsp)

await evaluate_test_cases(
    input_json_path="dspy_test_results.json",
    output_json_path="test_cases_with_scores.json",
    evaluator=evaluator
)
